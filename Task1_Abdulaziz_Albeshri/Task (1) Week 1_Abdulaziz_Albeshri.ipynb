# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

df = pd.read_csv('Task (1) Dataset.csv')

# %% [markdown]
# ### Handle Missing Values

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample()
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 7528  17:25:00   Wednesday            Unknown          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 7528  Junior high school                Employee              2-5yr
#
#      Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 7528      Motorcycle            Owner                 Unknown  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 7528   Going straight  Driver or rider            Male              Over 51
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 7528                 3     Self-employed               Normal
#
#      Pedestrian_movement                   Cause_of_accident Accident_severity
# 7528    Not a Pedestrian  Getting off the vehicle improperly     Slight Injury
#
# [1 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Service_year_of_vehicle'].unique()
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
df['Service_year_of_vehicle'] = df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0])

# %%
df['Defect_of_vehicle'].unique()
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
df['Defect_of_vehicle'] = df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0])

# %%
df['Work_of_casuality'].unique()
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
df['Work_of_casuality'] = df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0])

# %%
df['Fitness_of_casuality'].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0])

# %%
# Drop rows with null values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Casualty_severity'].unique()
# Out:
# array(['na', '3', '2', '1'], dtype=object)

# %%
df['Casualty_severity'] = df['Casualty_severity'].str.replace('na', '0')

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
df['Casualty_severity'] = df['Casualty_severity'].astype(int)

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                           8439                  8439.000000
# mean   1900-01-01 14:15:48.169214464                     2.038038
# min              1900-01-01 00:01:00                     1.000000
# 25%              1900-01-01 10:30:00                     2.000000
# 50%              1900-01-01 15:10:00                     2.000000
# 75%              1900-01-01 18:09:00                     2.000000
# max              1900-01-01 23:59:00                     7.000000
# std                              NaN                     0.680789
#
#        Number_of_casualties  Casualty_severity
# count           8439.000000        8439.000000
# mean               1.547340           1.855315
# min                1.000000           0.000000
# 25%                1.000000           0.000000
# 50%                1.000000           3.000000
# 75%                2.000000           3.000000
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                              Number_of_vehicles_involved  \
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.224609
# Casualty_severity                              -0.001054
#
#                              Number_of_casualties  Casualty_severity
# Number_of_vehicles_involved              0.224609          -0.001054
# Number_of_casualties                     1.000000           0.014157
# Casualty_severity                        0.014157           1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#Identify Outliers
plt.figure(figsize=(12, 6))
sns.boxplot(df['Number_of_casualties'])
plt.title('Number of Casualties')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['Number_of_vehicles_involved'])
plt.title('Number of Vehicles')
plt.show()

# %%
#remove outliers
# Function to remove outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers 
df = remove_outliers(df, "Number_of_casualties")

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.displot(data= df, x='Age_band_of_driver')
plt.title('Distribution of Driver\'s age group')
plt.xlabel('Age Band')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(data= df, x='Type_of_vehicle', height=10, aspect=3)
plt.title('Distribution of Vehicle Type')
plt.xlabel('Vehicle Type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(data= df, x='Sex_of_driver')
plt.title('Distribution of Driver\'s Sex')
plt.xlabel('Driver\'s Sex')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(data= df, x='Day_of_week', aspect=2)
plt.title('Distribution of Days')
plt.xlabel('Days')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(data= df, x='Accident_severity', aspect=2)
plt.title('Distribution of Accedint Severity')
plt.xlabel('Accedint Severity')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data= df, x='Number_of_vehicles_involved', y='Casualty_severity')
plt.title('Number of Vehicles Involved Vs Number of Casualities')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Casualities')
plt.show()

# %%
sns.scatterplot(data= df, x='Number_of_casualties', y='Casualty_severity')
plt.title('Number of Vehicles Involved Vs Number of Casualities')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Casualities')
plt.show()

# %%
sns.scatterplot(data= df, x='Number_of_vehicles_involved', y='Number_of_casualties')
plt.title('Number of Vehicles Involved Vs Number of Casualities')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Casualities')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
# Pie Chart
owner_counts = df['Accident_severity'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(owner_counts, labels=owner_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Accedint Severity')
plt.show()

# %%
# Pie Chart
owner_counts = df['Sex_of_driver'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(owner_counts, labels=owner_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Driver\s Sex')
plt.show()

# %%
# Pie Chart
owner_counts = df['Age_band_of_driver'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(owner_counts, labels=owner_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Age Band')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
Findings
- The number of vehicles involved is positively correlated number of casualities with 0.22 correlation
- The casualty severity is slightly positivly correlated with the number of casualities with 0.0011

- Sligh Injury takes up 85% of the the data which indicates that most of the accedint results in a slight injury
- Males are dominant in having accedints with 93%
- 18-30 and 31-50 age bands takes up to around 70% of the dataset
